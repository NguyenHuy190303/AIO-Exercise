# %%
# !pip install torcheval
# Out:
# Collecting torcheval
#   Downloading torcheval-0.0.7-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torcheval) (4.12.2)
# Downloading torcheval-0.0.7-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: torcheval
# Successfully installed torcheval-0.0.7

# %%
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torch import optim
from PIL import Image
from torchvision import transforms
import os
import matplotlib.pyplot as plt
import numpy as np
from torcheval.metrics.functional import peak_signal_noise_ratio
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(66)
from PIL import Image

# %%
import os

def extract_filepath(folder_root, type):
    lst_paths = []
    folder_dir = os.path.join(folder_root, type)
    for path in os.listdir(folder_dir):
        lst_paths.append(os.path.join(folder_dir, path))
    return lst_paths

train_paths = extract_filepath('/kaggle/input/khoa-lhr-image/Khoa_LHR_image', 'train')
val_paths = extract_filepath('/kaggle/input/khoa-lhr-image/Khoa_LHR_image', 'val')

# %%
img = Image.open(train_paths[0]).convert('RGB')
np.array(img).shape
# Out:
# (256, 256, 3)

# %%
torch.rand([])
# Out:
# tensor(0.4976)

# %%
batch_size = 8
low_img_height = 64
low_img_width = 64

class ImageDataset(Dataset):
    def __init__(self, paths ,low_img_height, low_img_width, is_train):
        super().__init__()
        self.low_img_height = low_img_height
        self.low_img_width = low_img_width
        self.paths = paths
        self.is_train = is_train
        self.resize = transforms.Resize((low_img_width, low_img_height))
    def __len__(self):
        return len(self.paths)
    
    def normalize(self, input_img, tgt_img):
        transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize([0.4914, 0.4822, 0.4465],
                                 [0.2470, 0.2435, 0.2616])
        ])
        
        input_img = transform(input_img)
        tgt_img = transform(tgt_img)
        return input_img, tgt_img
    
    def random_jitter(self, input_image, target_image):
        if torch.rand([]) < 0.5:
            input_image = transforms.functional.hflip(input_image)
            target_image = transforms.functional.hflip(target_image)

        return input_image, target_image
    def __getitem__(self, index):
        file_path = self.paths[index]
        img = Image.open(file_path).convert('RGB')
        img_input = self.resize(img)
        
        input_img, tgt_img = self.normalize(img_input, img)
        
        if self.is_train:
            input_img, tgt_img = self.random_jitter(input_img, tgt_img)

        return input_img, tgt_img

# %%
train_dataset = ImageDataset(train_paths , low_img_height, low_img_width, is_train = True)
val_dataset = ImageDataset(val_paths , low_img_height, low_img_width, is_train = False)

# %%
from torch.utils.data import DataLoader

# Tạo DataLoader cho training và validation dataset
train_loader = DataLoader(train_dataset,
                          batch_size=batch_size,
                          shuffle=True) 

val_loader = DataLoader(val_dataset,
                        batch_size=batch_size,
                        shuffle=False)

# %%
import torchvision
def imshow(img):
    np_img = img.numpy()
    plt.imshow(np.transpose(np_img, (1, 2, 0)))
    plt.show()

for i, (input_img, out_img) in enumerate(train_loader, 0):
    imshow(torchvision.utils.make_grid(input_img[:8]))
    break

# %% [markdown]
# ## Model

# %% [markdown]
# ### With skip-connection

# %%
class FirstFeature(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(FirstFeature, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 1, 1, 0, bias=False),
            nn.LeakyReLU()
        )

    def forward(self, x):
        return self.conv(x)


class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ConvBlock, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, 1, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, 3, 1, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(inplace=True),
        )

    def forward(self, x):
        return self.conv(x)


class Encoder(nn.Module):
    def __init__(self, in_channels, out_channels) -> None:
        super().__init__()
        self.encoder = nn.Sequential(
            nn.MaxPool2d(2),
            ConvBlock(in_channels, out_channels)
        )

    def forward(self, x):
        x = self.encoder(x)
        return x


class Decoder(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Decoder, self).__init__()
        self.conv = nn.Sequential(
            nn.UpsamplingBilinear2d(scale_factor=2),
            nn.Conv2d(in_channels, out_channels, 1, 1, 0, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(),
        )
        self.conv_block = ConvBlock(in_channels, out_channels)

    def forward(self, x, skip):
        x = self.conv(x)
        x = torch.concat([x, skip], dim=1)
        x = self.conv_block(x)
        return x


class FinalOutput(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(FinalOutput, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 1, 1, 0, bias=False),
            nn.Tanh()
        )

    def forward(self, x):
        return self.conv(x)


class SR_Unet(nn.Module):
    def __init__(
            self, n_channels=3, n_classes=3, tgt_size = 256
    ):
        super(SR_Unet, self).__init__()

        self.n_channels = n_channels
        self.n_classes = n_classes
        self.resize_fnc = transforms.Resize((tgt_size, tgt_size),
                                            antialias=True)
        self.in_conv1 = FirstFeature(n_channels, 64)
        self.in_conv2 = ConvBlock(64, 64)

        self.enc_1 = Encoder(64, 128)
        self.enc_2 = Encoder(128, 256)
        self.enc_3 = Encoder(256, 512)
        self.enc_4 = Encoder(512, 1024)

        self.dec_1 = Decoder(1024, 512)
        self.dec_2 = Decoder(512, 256)
        self.dec_3 = Decoder(256, 128)
        self.dec_4 = Decoder(128, 64)

        self.out_conv = FinalOutput(64, n_classes)

    def forward(self, x):
        x = self.resize_fnc(x)
        x = self.in_conv1(x)
        x1 = self.in_conv2(x)

        x2 = self.enc_1(x1)
        x3 = self.enc_2(x2)
        x4 = self.enc_3(x3)
        x5 = self.enc_4(x4)

        x = self.dec_1(x5, x4)
        x = self.dec_2(x, x3)
        x = self.dec_3(x, x2)
        x = self.dec_4(x, x1)

        x = self.out_conv(x)
        return x

# %%
unet_model = SR_Unet().to(device)
img = torch.ones(2, 3, 64, 64).to(device)
unet_model(img).shape
# Out:
# torch.Size([2, 3, 256, 256])

# %%
model = SR_Unet().to(device)

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.00005)

# %%
import time

def train_epoch(model, optimizer, criterion, train_dataloader, device, epoch=0,
                log_interval=50):
    model.train()
    total_psnr, total_count = 0, 0
    losses = []
    start_time = time.time()

    for idx, (inputs, labels) in enumerate(train_dataloader):
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        predictions = model(inputs)

        # compute loss
        loss = criterion(predictions, labels)
        losses.append(loss.item())

        # backward
        loss.backward()
        optimizer.step()

        total_psnr += peak_signal_noise_ratio(predictions, labels)
        total_count += 1
        if idx % log_interval == 0 and idx > 0:
            elapsed = time.time() - start_time
            print(
                "| epoch {:3d} | {:5d}/{:5d} batches "
                "| psnr {:8.3f}".format(
                    epoch, idx, len(train_dataloader), total_psnr / total_count
                )
            )
            total_psnr, total_count = 0, 0
            start_time = time.time()

    epoch_psnr = total_psnr / total_count
    epoch_loss = sum(losses) / len(losses)
    return epoch_psnr, epoch_loss

# %%
def evaluate_epoch(model, criterion, valid_dataloader, device):
    model.eval()
    total_psnr, total_count = 0, 0
    losses = []

    with torch.no_grad():
        for idx, (inputs, labels) in enumerate(valid_dataloader):
            inputs = inputs.to(device)
            labels = labels.to(device)

            predictions = model(inputs)

            loss = criterion(predictions, labels)
            losses.append(loss.item())

            total_psnr += peak_signal_noise_ratio(predictions, labels)
            total_count += 1

    epoch_psnr = total_psnr / total_count
    epoch_loss = sum(losses) / len(losses)
    return epoch_psnr, epoch_loss

# %%
import time

def train(model, model_name, save_model, optimizer, criterion, train_dataloader, valid_dataloader, num_epochs, device):
    train_psnrs, train_losses = [], []
    eval_psnrs, eval_losses = [], []
    best_psnr_eval = -1000
    times = []
    for epoch in range(1, num_epochs + 1):
        epoch_start_time = time.time()
        # Training
        train_psnr, train_loss = train_epoch(
            model, optimizer, criterion, train_dataloader, device, epoch)
        train_psnrs.append(train_psnr.cpu())
        train_losses.append(train_loss)

        # Evaluation
        eval_psnr, eval_loss = evaluate_epoch(
            model, criterion, valid_dataloader, device)
        eval_psnrs.append(eval_psnr.cpu())
        eval_losses.append(eval_loss)

        # Save best model
        if best_psnr_eval < eval_psnr:
            torch.save(model.state_dict(), save_model + f'/{model_name}.pt')
            best_psnr_eval = eval_psnr
        times.append(time.time() - epoch_start_time)
        # Print loss, psnr end epoch
        print("-" * 59)
        print(
            "| End of epoch {:3d} | Time: {:5.2f}s | Train psnr {:8.3f} | Train Loss {:8.3f} "
            "| Valid psnr {:8.3f} | Valid Loss {:8.3f} ".format(
                epoch, time.time() - epoch_start_time, train_psnr, train_loss, eval_psnr, eval_loss
            )
        )
        print("-" * 59)

    # Load best model
    model.load_state_dict(torch.load(save_model + f'/{model_name}.pt'))
    model.eval()
    metrics = {
        'train_psnr': train_psnrs,
        'train_loss': train_losses,
        'valid_psnr': eval_psnrs,
        'valid_loss': eval_losses,
        'time': times
    }
    return model, metrics

# %%
num_epochs = 100
save_model = './model'
os.makedirs(save_model, exist_ok=True)
model_name = 'SR_unet_skip_connection'

model, metrics = train(
    model, model_name, save_model, optimizer, criterion, train_loader, val_loader, num_epochs, device
)
# Out:
# | epoch   1 |    50/   86 batches | psnr   15.062
# -----------------------------------------------------------
# | End of epoch   1 | Time: 32.77s | Train psnr   16.438 | Train Loss    0.510 | Valid psnr   17.050 | Valid Loss    0.341
# -----------------------------------------------------------
# | epoch   2 |    50/   86 batches | psnr   17.027
# -----------------------------------------------------------
# | End of epoch   2 | Time: 28.68s | Train psnr   17.229 | Train Loss    0.343 | Valid psnr   17.622 | Valid Loss    0.300
# -----------------------------------------------------------
# | epoch   3 |    50/   86 batches | psnr   17.396
# -----------------------------------------------------------
# | End of epoch   3 | Time: 28.60s | Train psnr   17.374 | Train Loss    0.320 | Valid psnr   17.815 | Valid Loss    0.288
# -----------------------------------------------------------
# | epoch   4 |    50/   86 batches | psnr   17.663
# -----------------------------------------------------------
# | End of epoch   4 | Time: 28.66s | Train psnr   17.719 | Train Loss    0.302 | Valid psnr   18.053 | Valid Loss    0.273
# -----------------------------------------------------------
# | epoch   5 |    50/   86 batches | psnr   17.932
# -----------------------------------------------------------
# | End of epoch   5 | Time: 28.57s | Train psnr   17.768 | Train Loss    0.288 | Valid psnr   18.134 | Valid Loss    0.268
# -----------------------------------------------------------
# | epoch   6 |    50/   86 batches | psnr   18.215
# -----------------------------------------------------------
# | End of epoch   6 | Time: 28.38s | Train psnr   17.729 | Train Loss    0.280 | Valid psnr   18.343 | Valid Loss    0.257
# -----------------------------------------------------------
# | epoch   7 |    50/   86 batches | psnr   18.174
# -----------------------------------------------------------
# | End of epoch   7 | Time: 28.27s | Train psnr   17.988 | Train Loss    0.270 | Valid psnr   18.431 | Valid Loss    0.252
# -----------------------------------------------------------
# | epoch   8 |    50/   86 batches | psnr   18.173
# -----------------------------------------------------------
# | End of epoch   8 | Time: 28.37s | Train psnr   18.369 | Train Loss    0.265 | Valid psnr   18.532 | Valid Loss    0.246
# -----------------------------------------------------------
# | epoch   9 |    50/   86 batches | psnr   18.304
# -----------------------------------------------------------
# | End of epoch   9 | Time: 28.36s | Train psnr   18.227 | Train Loss    0.262 | Valid psnr   18.537 | Valid Loss    0.246
# -----------------------------------------------------------
# | epoch  10 |    50/   86 batches | psnr   18.235
# -----------------------------------------------------------
# | End of epoch  10 | Time: 28.13s | Train psnr   18.388 | Train Loss    0.259 | Valid psnr   18.469 | Valid Loss    0.249
# -----------------------------------------------------------
# | epoch  11 |    50/   86 batches | psnr   18.295
# -----------------------------------------------------------
# | End of epoch  11 | Time: 28.34s | Train psnr   18.591 | Train Loss    0.252 | Valid psnr   18.636 | Valid Loss    0.241
# -----------------------------------------------------------
# | epoch  12 |    50/   86 batches | psnr   18.401
# -----------------------------------------------------------
# | End of epoch  12 | Time: 28.33s | Train psnr   18.690 | Train Loss    0.250 | Valid psnr   18.699 | Valid Loss    0.237
# -----------------------------------------------------------
# | epoch  13 |    50/   86 batches | psnr   18.695
# -----------------------------------------------------------
# | End of epoch  13 | Time: 28.07s | Train psnr   18.164 | Train Loss    0.251 | Valid psnr   18.581 | Valid Loss    0.243
# -----------------------------------------------------------
# | epoch  14 |    50/   86 batches | psnr   18.560
# -----------------------------------------------------------
# | End of epoch  14 | Time: 28.61s | Train psnr   18.500 | Train Loss    0.246 | Valid psnr   18.731 | Valid Loss    0.236
# -----------------------------------------------------------
# | epoch  15 |    50/   86 batches | psnr   18.667
# -----------------------------------------------------------
# | End of epoch  15 | Time: 28.33s | Train psnr   18.474 | Train Loss    0.245 | Valid psnr   18.697 | Valid Loss    0.237
# -----------------------------------------------------------
# | epoch  16 |    50/   86 batches | psnr   18.580
# -----------------------------------------------------------
# | End of epoch  16 | Time: 28.47s | Train psnr   18.602 | Train Loss    0.243 | Valid psnr   18.787 | Valid Loss    0.233
# -----------------------------------------------------------
# | epoch  17 |    50/   86 batches | psnr   18.969
# -----------------------------------------------------------
# | End of epoch  17 | Time: 28.02s | Train psnr   18.062 | Train Loss    0.244 | Valid psnr   18.773 | Valid Loss    0.234
# -----------------------------------------------------------
# | epoch  18 |    50/   86 batches | psnr   18.442
# -----------------------------------------------------------
# | End of epoch  18 | Time: 28.19s | Train psnr   18.952 | Train Loss    0.242 | Valid psnr   18.821 | Valid Loss    0.231
# -----------------------------------------------------------
# | epoch  19 |    50/   86 batches | psnr   18.733
# -----------------------------------------------------------
# | End of epoch  19 | Time: 27.95s | Train psnr   18.587 | Train Loss    0.239 | Valid psnr   18.806 | Valid Loss    0.232
# -----------------------------------------------------------
# | epoch  20 |    50/   86 batches | psnr   18.691
# -----------------------------------------------------------
# | End of epoch  20 | Time: 28.24s | Train psnr   18.634 | Train Loss    0.237 | Valid psnr   18.833 | Valid Loss    0.231
# -----------------------------------------------------------
# | epoch  21 |    50/   86 batches | psnr   18.700
# -----------------------------------------------------------
# | End of epoch  21 | Time: 28.37s | Train psnr   18.636 | Train Loss    0.238 | Valid psnr   18.839 | Valid Loss    0.230
# -----------------------------------------------------------
# | epoch  22 |    50/   86 batches | psnr   18.567
# -----------------------------------------------------------
# | End of epoch  22 | Time: 28.01s | Train psnr   18.870 | Train Loss    0.238 | Valid psnr   18.808 | Valid Loss    0.232
# -----------------------------------------------------------
# | epoch  23 |    50/   86 batches | psnr   18.849
# -----------------------------------------------------------
# | End of epoch  23 | Time: 28.45s | Train psnr   18.601 | Train Loss    0.236 | Valid psnr   18.854 | Valid Loss    0.230
# -----------------------------------------------------------
# | epoch  24 |    50/   86 batches | psnr   18.738
# -----------------------------------------------------------
# | End of epoch  24 | Time: 28.38s | Train psnr   18.735 | Train Loss    0.235 | Valid psnr   18.854 | Valid Loss    0.229
# -----------------------------------------------------------
# | epoch  25 |    50/   86 batches | psnr   18.710
# -----------------------------------------------------------
# | End of epoch  25 | Time: 28.56s | Train psnr   18.817 | Train Loss    0.234 | Valid psnr   18.877 | Valid Loss    0.228
# -----------------------------------------------------------
# | epoch  26 |    50/   86 batches | psnr   18.715
# -----------------------------------------------------------
# | End of epoch  26 | Time: 28.03s | Train psnr   18.748 | Train Loss    0.235 | Valid psnr   18.877 | Valid Loss    0.228
# -----------------------------------------------------------
# | epoch  27 |    50/   86 batches | psnr   18.624
# -----------------------------------------------------------
# | End of epoch  27 | Time: 28.29s | Train psnr   18.924 | Train Loss    0.234 | Valid psnr   18.887 | Valid Loss    0.228
# -----------------------------------------------------------
# | epoch  28 |    50/   86 batches | psnr   18.736
# -----------------------------------------------------------
# | End of epoch  28 | Time: 28.02s | Train psnr   18.857 | Train Loss    0.234 | Valid psnr   18.876 | Valid Loss    0.228
# -----------------------------------------------------------
# | epoch  29 |    50/   86 batches | psnr   18.828
# -----------------------------------------------------------
# | End of epoch  29 | Time: 28.29s | Train psnr   18.779 | Train Loss    0.232 | Valid psnr   18.895 | Valid Loss    0.227
# -----------------------------------------------------------
# | epoch  30 |    50/   86 batches | psnr   18.726
# -----------------------------------------------------------
# | End of epoch  30 | Time: 28.50s | Train psnr   18.996 | Train Loss    0.231 | Valid psnr   18.913 | Valid Loss    0.227
# -----------------------------------------------------------
# | epoch  31 |    50/   86 batches | psnr   18.859
# -----------------------------------------------------------
# | End of epoch  31 | Time: 28.57s | Train psnr   18.743 | Train Loss    0.231 | Valid psnr   18.910 | Valid Loss    0.227
# -----------------------------------------------------------
# | epoch  32 |    50/   86 batches | psnr   18.700
# -----------------------------------------------------------
# | End of epoch  32 | Time: 28.47s | Train psnr   18.926 | Train Loss    0.231 | Valid psnr   18.909 | Valid Loss    0.227
# -----------------------------------------------------------
# | epoch  33 |    50/   86 batches | psnr   18.745
# -----------------------------------------------------------
# | End of epoch  33 | Time: 28.97s | Train psnr   18.994 | Train Loss    0.230 | Valid psnr   18.925 | Valid Loss    0.226
# -----------------------------------------------------------
# | epoch  34 |    50/   86 batches | psnr   18.821
# -----------------------------------------------------------
# | End of epoch  34 | Time: 28.95s | Train psnr   18.820 | Train Loss    0.230 | Valid psnr   18.928 | Valid Loss    0.226
# -----------------------------------------------------------
# | epoch  35 |    50/   86 batches | psnr   19.131
# -----------------------------------------------------------
# | End of epoch  35 | Time: 28.41s | Train psnr   18.452 | Train Loss    0.230 | Valid psnr   18.886 | Valid Loss    0.228
# -----------------------------------------------------------
# | epoch  36 |    50/   86 batches | psnr   18.909
# -----------------------------------------------------------
# | End of epoch  36 | Time: 28.51s | Train psnr   18.747 | Train Loss    0.230 | Valid psnr   18.922 | Valid Loss    0.226
# -----------------------------------------------------------
# | epoch  37 |    50/   86 batches | psnr   18.798
# -----------------------------------------------------------
# | End of epoch  37 | Time: 28.46s | Train psnr   18.981 | Train Loss    0.230 | Valid psnr   18.915 | Valid Loss    0.227
# -----------------------------------------------------------
# | epoch  38 |    50/   86 batches | psnr   18.691
# -----------------------------------------------------------
# | End of epoch  38 | Time: 28.79s | Train psnr   19.059 | Train Loss    0.230 | Valid psnr   18.942 | Valid Loss    0.225
# -----------------------------------------------------------
# | epoch  39 |    50/   86 batches | psnr   18.964
# -----------------------------------------------------------
# | End of epoch  39 | Time: 28.65s | Train psnr   18.839 | Train Loss    0.227 | Valid psnr   18.946 | Valid Loss    0.225
# -----------------------------------------------------------
# | epoch  40 |    50/   86 batches | psnr   18.868
# -----------------------------------------------------------
# | End of epoch  40 | Time: 28.47s | Train psnr   18.953 | Train Loss    0.227 | Valid psnr   18.941 | Valid Loss    0.225
# -----------------------------------------------------------
# | epoch  41 |    50/   86 batches | psnr   18.865
# -----------------------------------------------------------
# | End of epoch  41 | Time: 28.68s | Train psnr   18.986 | Train Loss    0.228 | Valid psnr   18.950 | Valid Loss    0.225
# -----------------------------------------------------------
# | epoch  42 |    50/   86 batches | psnr   18.899
# -----------------------------------------------------------
# | End of epoch  42 | Time: 28.36s | Train psnr   18.882 | Train Loss    0.228 | Valid psnr   18.937 | Valid Loss    0.225
# -----------------------------------------------------------
# | epoch  43 |    50/   86 batches | psnr   18.949
# -----------------------------------------------------------
# | End of epoch  43 | Time: 28.47s | Train psnr   18.884 | Train Loss    0.226 | Valid psnr   18.956 | Valid Loss    0.225
# -----------------------------------------------------------
# | epoch  44 |    50/   86 batches | psnr   18.934
# -----------------------------------------------------------
# | End of epoch  44 | Time: 28.25s | Train psnr   18.833 | Train Loss    0.226 | Valid psnr   18.941 | Valid Loss    0.225
# -----------------------------------------------------------
# | epoch  45 |    50/   86 batches | psnr   19.128
# -----------------------------------------------------------
# | End of epoch  45 | Time: 28.24s | Train psnr   18.604 | Train Loss    0.226 | Valid psnr   18.940 | Valid Loss    0.225
# -----------------------------------------------------------
# | epoch  46 |    50/   86 batches | psnr   19.059
# -----------------------------------------------------------
# | End of epoch  46 | Time: 28.33s | Train psnr   18.766 | Train Loss    0.227 | Valid psnr   18.950 | Valid Loss    0.225
# -----------------------------------------------------------
# | epoch  47 |    50/   86 batches | psnr   18.852
# -----------------------------------------------------------
# | End of epoch  47 | Time: 28.25s | Train psnr   18.984 | Train Loss    0.226 | Valid psnr   18.951 | Valid Loss    0.225
# -----------------------------------------------------------
# | epoch  48 |    50/   86 batches | psnr   18.977
# -----------------------------------------------------------
# | End of epoch  48 | Time: 28.18s | Train psnr   18.902 | Train Loss    0.226 | Valid psnr   18.953 | Valid Loss    0.225
# -----------------------------------------------------------
# | epoch  49 |    50/   86 batches | psnr   19.147
# -----------------------------------------------------------
# | End of epoch  49 | Time: 28.18s | Train psnr   18.663 | Train Loss    0.225 | Valid psnr   18.950 | Valid Loss    0.225
# -----------------------------------------------------------
# | epoch  50 |    50/   86 batches | psnr   18.713
# -----------------------------------------------------------
# | End of epoch  50 | Time: 28.54s | Train psnr   19.247 | Train Loss    0.224 | Valid psnr   18.964 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  51 |    50/   86 batches | psnr   18.932
# -----------------------------------------------------------
# | End of epoch  51 | Time: 28.54s | Train psnr   18.963 | Train Loss    0.225 | Valid psnr   18.965 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  52 |    50/   86 batches | psnr   18.889
# -----------------------------------------------------------
# | End of epoch  52 | Time: 28.19s | Train psnr   19.109 | Train Loss    0.225 | Valid psnr   18.949 | Valid Loss    0.225
# -----------------------------------------------------------
# | epoch  53 |    50/   86 batches | psnr   18.862
# -----------------------------------------------------------
# | End of epoch  53 | Time: 28.50s | Train psnr   19.108 | Train Loss    0.223 | Valid psnr   18.969 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  54 |    50/   86 batches | psnr   19.151
# -----------------------------------------------------------
# | End of epoch  54 | Time: 28.10s | Train psnr   18.779 | Train Loss    0.223 | Valid psnr   18.956 | Valid Loss    0.225
# -----------------------------------------------------------
# | epoch  55 |    50/   86 batches | psnr   18.900
# -----------------------------------------------------------
# | End of epoch  55 | Time: 28.47s | Train psnr   19.061 | Train Loss    0.223 | Valid psnr   18.970 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  56 |    50/   86 batches | psnr   18.936
# -----------------------------------------------------------
# | End of epoch  56 | Time: 28.20s | Train psnr   18.980 | Train Loss    0.223 | Valid psnr   18.962 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  57 |    50/   86 batches | psnr   18.960
# -----------------------------------------------------------
# | End of epoch  57 | Time: 27.99s | Train psnr   18.947 | Train Loss    0.223 | Valid psnr   18.968 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  58 |    50/   86 batches | psnr   19.101
# -----------------------------------------------------------
# | End of epoch  58 | Time: 28.05s | Train psnr   18.891 | Train Loss    0.222 | Valid psnr   18.970 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  59 |    50/   86 batches | psnr   18.871
# -----------------------------------------------------------
# | End of epoch  59 | Time: 28.41s | Train psnr   19.183 | Train Loss    0.221 | Valid psnr   18.973 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  60 |    50/   86 batches | psnr   18.957
# -----------------------------------------------------------
# | End of epoch  60 | Time: 28.10s | Train psnr   19.046 | Train Loss    0.223 | Valid psnr   18.958 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  61 |    50/   86 batches | psnr   19.144
# -----------------------------------------------------------
# | End of epoch  61 | Time: 28.36s | Train psnr   18.821 | Train Loss    0.222 | Valid psnr   18.975 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  62 |    50/   86 batches | psnr   19.038
# -----------------------------------------------------------
# | End of epoch  62 | Time: 28.04s | Train psnr   19.045 | Train Loss    0.221 | Valid psnr   18.966 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  63 |    50/   86 batches | psnr   19.230
# -----------------------------------------------------------
# | End of epoch  63 | Time: 28.10s | Train psnr   18.768 | Train Loss    0.221 | Valid psnr   18.970 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  64 |    50/   86 batches | psnr   18.996
# -----------------------------------------------------------
# | End of epoch  64 | Time: 28.45s | Train psnr   19.121 | Train Loss    0.221 | Valid psnr   18.976 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  65 |    50/   86 batches | psnr   19.031
# -----------------------------------------------------------
# | End of epoch  65 | Time: 28.15s | Train psnr   19.022 | Train Loss    0.220 | Valid psnr   18.975 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  66 |    50/   86 batches | psnr   18.848
# -----------------------------------------------------------
# | End of epoch  66 | Time: 28.28s | Train psnr   19.359 | Train Loss    0.220 | Valid psnr   18.971 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  67 |    50/   86 batches | psnr   19.175
# -----------------------------------------------------------
# | End of epoch  67 | Time: 28.17s | Train psnr   18.894 | Train Loss    0.220 | Valid psnr   18.972 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  68 |    50/   86 batches | psnr   19.216
# -----------------------------------------------------------
# | End of epoch  68 | Time: 28.09s | Train psnr   18.972 | Train Loss    0.219 | Valid psnr   18.961 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  69 |    50/   86 batches | psnr   19.057
# -----------------------------------------------------------
# | End of epoch  69 | Time: 28.16s | Train psnr   19.019 | Train Loss    0.219 | Valid psnr   18.973 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  70 |    50/   86 batches | psnr   19.055
# -----------------------------------------------------------
# | End of epoch  70 | Time: 28.19s | Train psnr   19.119 | Train Loss    0.219 | Valid psnr   18.962 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  71 |    50/   86 batches | psnr   19.041
# -----------------------------------------------------------
# | End of epoch  71 | Time: 28.11s | Train psnr   19.052 | Train Loss    0.219 | Valid psnr   18.975 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  72 |    50/   86 batches | psnr   19.091
# -----------------------------------------------------------
# | End of epoch  72 | Time: 28.17s | Train psnr   18.979 | Train Loss    0.219 | Valid psnr   18.962 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  73 |    50/   86 batches | psnr   18.935
# -----------------------------------------------------------
# | End of epoch  73 | Time: 28.07s | Train psnr   19.259 | Train Loss    0.219 | Valid psnr   18.973 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  74 |    50/   86 batches | psnr   18.884
# -----------------------------------------------------------
# | End of epoch  74 | Time: 28.20s | Train psnr   19.327 | Train Loss    0.218 | Valid psnr   18.972 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  75 |    50/   86 batches | psnr   19.210
# -----------------------------------------------------------
# | End of epoch  75 | Time: 28.03s | Train psnr   18.952 | Train Loss    0.218 | Valid psnr   18.965 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  76 |    50/   86 batches | psnr   19.261
# -----------------------------------------------------------
# | End of epoch  76 | Time: 28.10s | Train psnr   18.804 | Train Loss    0.218 | Valid psnr   18.947 | Valid Loss    0.225
# -----------------------------------------------------------
# | epoch  77 |    50/   86 batches | psnr   19.152
# -----------------------------------------------------------
# | End of epoch  77 | Time: 28.32s | Train psnr   18.977 | Train Loss    0.218 | Valid psnr   18.981 | Valid Loss    0.223
# -----------------------------------------------------------
# | epoch  78 |    50/   86 batches | psnr   19.359
# -----------------------------------------------------------
# | End of epoch  78 | Time: 28.11s | Train psnr   18.836 | Train Loss    0.218 | Valid psnr   18.975 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  79 |    50/   86 batches | psnr   19.186
# -----------------------------------------------------------
# | End of epoch  79 | Time: 28.03s | Train psnr   18.974 | Train Loss    0.219 | Valid psnr   18.771 | Valid Loss    0.233
# -----------------------------------------------------------
# | epoch  80 |    50/   86 batches | psnr   18.942
# -----------------------------------------------------------
# | End of epoch  80 | Time: 28.22s | Train psnr   19.184 | Train Loss    0.219 | Valid psnr   18.979 | Valid Loss    0.223
# -----------------------------------------------------------
# | epoch  81 |    50/   86 batches | psnr   19.138
# -----------------------------------------------------------
# | End of epoch  81 | Time: 28.18s | Train psnr   19.000 | Train Loss    0.218 | Valid psnr   18.976 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  82 |    50/   86 batches | psnr   19.180
# -----------------------------------------------------------
# | End of epoch  82 | Time: 28.38s | Train psnr   19.123 | Train Loss    0.217 | Valid psnr   18.968 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  83 |    50/   86 batches | psnr   19.131
# -----------------------------------------------------------
# | End of epoch  83 | Time: 28.14s | Train psnr   19.006 | Train Loss    0.217 | Valid psnr   18.980 | Valid Loss    0.223
# -----------------------------------------------------------
# | epoch  84 |    50/   86 batches | psnr   19.097
# -----------------------------------------------------------
# | End of epoch  84 | Time: 28.51s | Train psnr   19.123 | Train Loss    0.216 | Valid psnr   18.981 | Valid Loss    0.223
# -----------------------------------------------------------
# | epoch  85 |    50/   86 batches | psnr   19.226
# -----------------------------------------------------------
# | End of epoch  85 | Time: 28.54s | Train psnr   19.074 | Train Loss    0.215 | Valid psnr   18.984 | Valid Loss    0.223
# -----------------------------------------------------------
# | epoch  86 |    50/   86 batches | psnr   18.911
# -----------------------------------------------------------
# | End of epoch  86 | Time: 28.26s | Train psnr   19.389 | Train Loss    0.216 | Valid psnr   18.982 | Valid Loss    0.223
# -----------------------------------------------------------
# | epoch  87 |    50/   86 batches | psnr   19.117
# -----------------------------------------------------------
# | End of epoch  87 | Time: 28.12s | Train psnr   19.168 | Train Loss    0.216 | Valid psnr   18.977 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  88 |    50/   86 batches | psnr   19.110
# -----------------------------------------------------------
# | End of epoch  88 | Time: 28.15s | Train psnr   19.171 | Train Loss    0.216 | Valid psnr   18.976 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  89 |    50/   86 batches | psnr   19.093
# -----------------------------------------------------------
# | End of epoch  89 | Time: 28.19s | Train psnr   19.188 | Train Loss    0.215 | Valid psnr   18.975 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  90 |    50/   86 batches | psnr   19.187
# -----------------------------------------------------------
# | End of epoch  90 | Time: 28.10s | Train psnr   19.030 | Train Loss    0.215 | Valid psnr   18.979 | Valid Loss    0.223
# -----------------------------------------------------------
# | epoch  91 |    50/   86 batches | psnr   19.264
# -----------------------------------------------------------
# | End of epoch  91 | Time: 28.25s | Train psnr   18.957 | Train Loss    0.214 | Valid psnr   18.974 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  92 |    50/   86 batches | psnr   19.109
# -----------------------------------------------------------
# | End of epoch  92 | Time: 28.16s | Train psnr   19.218 | Train Loss    0.215 | Valid psnr   18.975 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  93 |    50/   86 batches | psnr   19.304
# -----------------------------------------------------------
# | End of epoch  93 | Time: 28.19s | Train psnr   18.906 | Train Loss    0.214 | Valid psnr   18.981 | Valid Loss    0.223
# -----------------------------------------------------------
# | epoch  94 |    50/   86 batches | psnr   19.234
# -----------------------------------------------------------
# | End of epoch  94 | Time: 28.21s | Train psnr   19.060 | Train Loss    0.215 | Valid psnr   18.969 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  95 |    50/   86 batches | psnr   19.150
# -----------------------------------------------------------
# | End of epoch  95 | Time: 28.41s | Train psnr   19.196 | Train Loss    0.214 | Valid psnr   18.982 | Valid Loss    0.223
# -----------------------------------------------------------
# | epoch  96 |    50/   86 batches | psnr   19.073
# -----------------------------------------------------------
# | End of epoch  96 | Time: 28.42s | Train psnr   19.271 | Train Loss    0.214 | Valid psnr   18.983 | Valid Loss    0.223
# -----------------------------------------------------------
# | epoch  97 |    50/   86 batches | psnr   19.356
# -----------------------------------------------------------
# | End of epoch  97 | Time: 28.48s | Train psnr   18.929 | Train Loss    0.215 | Valid psnr   18.975 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  98 |    50/   86 batches | psnr   19.015
# -----------------------------------------------------------
# | End of epoch  98 | Time: 28.50s | Train psnr   19.366 | Train Loss    0.213 | Valid psnr   18.974 | Valid Loss    0.224
# -----------------------------------------------------------
# | epoch  99 |    50/   86 batches | psnr   19.118
# -----------------------------------------------------------
# | End of epoch  99 | Time: 28.29s | Train psnr   19.272 | Train Loss    0.214 | Valid psnr   18.982 | Valid Loss    0.223
# -----------------------------------------------------------
# | epoch 100 |    50/   86 batches | psnr   19.175
# -----------------------------------------------------------
# | End of epoch 100 | Time: 28.31s | Train psnr   19.184 | Train Loss    0.214 | Valid psnr   18.973 | Valid Loss    0.224
# -----------------------------------------------------------
# <ipython-input-15-35e566d6dbce>:38: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(save_model + f'/{model_name}.pt'))

# %%
import matplotlib.pyplot as plt

def plot_result(num_epochs, train_psnrs, valid_psnrs, train_losses, eval_losses):
    epochs = list(range(num_epochs))
    fig, axs = plt.subplots(nrows = 1, ncols =2 , figsize = (12,6))
    axs[0].plot(epochs, train_psnrs, label = "Training")
    axs[0].plot(epochs, valid_psnrs, label = "Evaluation")
    axs[1].plot(epochs, train_losses, label = "Training")
    axs[1].plot(epochs, eval_losses, label = "Evaluation")
    axs[0].set_xlabel("Epochs")
    axs[1].set_xlabel("Epochs")
    axs[0].set_ylabel("psnrs")
    axs[1].set_ylabel("Loss")
    plt.legend()

plot_result(
    num_epochs,
    metrics["train_psnr"],
    metrics["valid_psnr"],
    metrics["train_loss"],
    metrics["valid_loss"]
)

# %%
import matplotlib.pyplot as plt
import numpy as np

def predict_and_display(model, dataloader, device):
    model.eval()
    for inputs, labels in dataloader:
        inputs, labels = inputs.to(device), labels.to(device)
        predicts = model(inputs)

        inputs, labels, predicts = inputs.cpu().detach().numpy(), labels.cpu().detach().numpy(), predicts.cpu().detach().numpy()
        display_list = [inputs[-1].transpose((1, 2, 0)), labels[-1].transpose((1, 2, 0)), predicts[-1].transpose((1, 2, 0))]
        title = ['Input', 'Real', 'Predicted']

        plt.figure(figsize=(15, 20))
        for i in range(3):
            plt.subplot(1, 3, i+1)
            plt.title(title[i])
            plt.imshow((display_list[i] + 1) / 2)
            plt.axis('off')
        
        plt.show()

        break
predict_and_display(model, train_loader, device)
